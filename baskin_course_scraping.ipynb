# %%
pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
import re
from bs4 import BeautifulSoup
from pathlib import Path
import csv


# url for UCSC Baskin courses
bsoe_base_url = "https://courses.engineering.ucsc.edu/"

# fetch the base page and parse the department links
base = requests.get(bsoe_base_url)
soup_base = BeautifulSoup(base.content, 'html.parser')
department_menu = soup_base.find("ul", id="main-menu")

# gather department links
department_links = []
for department in department_menu:
    if department != "\n":
        if link := department.find("a"):
            department_links.append(
                (bsoe_base_url + link["href"][1:], link.text))

department_links.pop()
print(department_links)

# initialize a list to hold course data
course_data = []

# iterate through department links and extract course information
for link, name in department_links:
    r = requests.get(link)
    soup = BeautifulSoup(r.content, 'html.parser')
    table = soup.find("table")
    sections = table.find_all("li")

    for section in sections:
        link = section.find("a")
        section_num = link.text
        class_url = link["href"]
        class_res = re.search(
            "\/[a-z]*\/([A-Z0-9]*)\/([A-Za-z0-9]*)\/", class_url)

        if class_res:
            class_name = class_res.group(1)  # extract class name
            quarter = class_res.group(2)  # extract quarter
            full_prof = section.contents[3].strip() if len(section.contents) > 3 else ''

            # extract professor name, checking if it exists
            prof_res = re.search(r"([ a-zA-ZÀ-ž-.]*) \(|(Staff)", full_prof)
            professor_name = prof_res.group(1) or prof_res.group(2)

            # skip the course if no professor is found
            # case where the class is not taught at all that school year
            if not professor_name or professor_name.strip().lower() == "staff":
                continue

            # prepare the data for CSV
            course_data.append({
                "department": name,
                "quarter": quarter,
                "class_name": class_name,
                "professor_name": professor_name,
                "section": section_num,
            })
            print(course_data[-1])  # print the last added data

# write data to a CSV file
csv_file = 'ucsc_baskin_courses_2024.csv'
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    fieldnames = ["department", "quarter", "class_name", "professor_name", "section"]
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerows(course_data)

print(f"\nData successfully saved to {csv_file}")
# Out:
# [('https://courses.engineering.ucsc.edu/courses/am', 'Applied Mathematics'), ('https://courses.engineering.ucsc.edu/courses/bme', 'Biomolecular Engineering'), ('https://courses.engineering.ucsc.edu/courses/cmpm', 'Computational Media'), ('https://courses.engineering.ucsc.edu/courses/cse', 'Computer Science and Engineering'), ('https://courses.engineering.ucsc.edu/courses/ece', 'Electrical and Computer Engineering'), ('https://courses.engineering.ucsc.edu/courses/game', 'Games and Playable Media'), ('https://courses.engineering.ucsc.edu/courses/hci', 'Human Computer Interaction'), ('https://courses.engineering.ucsc.edu/courses/nlp', 'Natural Language Processing'), ('https://courses.engineering.ucsc.edu/courses/game', 'Serious Games'), ('https://courses.engineering.ucsc.edu/courses/stat', 'Statistics'), ('https://courses.engineering.ucsc.edu/courses/tim', 'Technology & Information Management')]
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM3', 'professor_name': 'Jelliffe Jackson', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM10', 'professor_name': 'Yonatan Katznelson', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM10', 'professor_name': 'Jonathan Rice Katznelson', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM10', 'professor_name': 'Jonathan Rice Katznelson', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM11A', 'professor_name': 'Julie Simons', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM11A', 'professor_name': 'Julie Simons', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM11A', 'professor_name': 'Julie Simons', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM11B', 'professor_name': 'Yonatan Katznelson', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM11B', 'professor_name': 'Jelliffe Jackson', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM11B', 'professor_name': 'Julie Simons', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM20', 'professor_name': 'Jonathan Rice Katznelson', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM20', 'professor_name': 'Qi Gong', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM20', 'professor_name': 'Jonathan Rice Katznelson', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM30', 'professor_name': 'Javier Gonzalez-Rocha', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM100', 'professor_name': 'Hongyun Wang', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM100', 'professor_name': 'Ashesh Chattopadhyay', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM107', 'professor_name': 'Nic Brummell', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM112', 'professor_name': 'Hongyun Wang', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM114', 'professor_name': 'Qi Gong', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM129', 'professor_name': 'Sean Michael Riedel', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM147', 'professor_name': 'Javier Gonzalez-Rocha', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM160', 'professor_name': 'Ashesh Chattopadhyay', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM170A', 'professor_name': 'Pascale Garaud', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM212', 'professor_name': 'Pascale Garaud', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM213A', 'professor_name': 'Dongwook Lee', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM213B', 'professor_name': 'Javier Gonzalez-Rocha', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM217', 'professor_name': 'Nic Brummell', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM224', 'professor_name': 'Daniele Venturi', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM229', 'professor_name': 'Marcella Gomez', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM238', 'professor_name': 'Daniele Venturi', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM250', 'professor_name': 'Nic Brummell', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM260', 'professor_name': 'Dongwook Lee', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM275', 'professor_name': 'Nic Brummell', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM280B', 'professor_name': 'Javier Gonzalez-Rocha', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM280B', 'professor_name': 'Marcella Gomez', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM280B', 'professor_name': 'Ashesh Chattopadhyay', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Fall24', 'class_name': 'AM280C', 'professor_name': 'Dongwook Lee', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Winter25', 'class_name': 'AM280C', 'professor_name': 'Nicholas H Brummell', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM280C', 'professor_name': 'Pascale Garaud', 'section': 'Section 01'}
# {'department': 'Applied Mathematics', 'quarter': 'Spring25', 'class_name': 'AM280C', 'professor_name': 'Sang Eun Chun', 'section': 'Section 02'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME5', 'professor_name': 'Dianne G Hendricks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME5', 'professor_name': 'Nader Pourmand', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME18', 'professor_name': 'David Haussler', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME21L', 'professor_name': 'Nader Pourmand', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME21L', 'professor_name': 'Nader Pourmand', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME22L', 'professor_name': 'Dianne G Hendricks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME22L', 'professor_name': 'Dianne G Hendricks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME23L', 'professor_name': 'David L Bernick', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME23L', 'professor_name': 'David L Bernick', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME80G', 'professor_name': 'Karen Miga', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME80H', 'professor_name': 'Karen Miga', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME105', 'professor_name': 'Angela Brooks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME110', 'professor_name': 'Angela Brooks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME110', 'professor_name': 'Alexander Ioannidis', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME110', 'professor_name': 'Ali Shariati', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME110', 'professor_name': 'Vanessa D Jonsson', 'section': 'Section 02'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME118', 'professor_name': 'David Haussler', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME122H', 'professor_name': 'David L Bernick', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME128', 'professor_name': 'Andy H.W. Yeh', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME128L', 'professor_name': 'Andy H.W. Yeh', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME128L', 'professor_name': 'Andy Yeh', 'section': 'Section 02'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME129A', 'professor_name': 'Rebecca DuBois', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME129B', 'professor_name': 'Russ Corbett-Detig', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME129C', 'professor_name': 'Nader Pourmand', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME130', 'professor_name': 'Ed Green', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME132', 'professor_name': 'Shelbi L Russell', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME160', 'professor_name': 'Tal Sharf', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME160', 'professor_name': 'David L Bernick', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME163', 'professor_name': 'Christopher S Vollmers', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME175', 'professor_name': 'Ed Green', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME177', 'professor_name': 'Ali Shariati', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME180', 'professor_name': 'David L Bernick', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME185', 'professor_name': 'Dianne G Hendricks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME185', 'professor_name': 'Dianne G Hendricks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME185', 'professor_name': 'Dianne G Hendricks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME188A', 'professor_name': 'David L Bernick', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME201', 'professor_name': 'Joshua M Stuart', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME205', 'professor_name': 'Russ Corbett-Detig', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME218', 'professor_name': 'David Haussler', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME230A', 'professor_name': 'Vanessa D Jonsson', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME232', 'professor_name': 'Shelbi L Russell', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME263', 'professor_name': 'Chris Vollmers', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME272', 'professor_name': 'Daniel H. Kim', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME275', 'professor_name': 'Ed Green', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME278', 'professor_name': 'Daniel H. Kim', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME280B', 'professor_name': 'Nader Pourmand', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME280B', 'professor_name': 'Daniel H. Kim', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME280B', 'professor_name': 'Angela Brooks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281D', 'professor_name': 'Rebecca DuBois', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281D', 'professor_name': 'Rebecca DuBois', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281D', 'professor_name': 'Rebecca DuBois', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281E', 'professor_name': 'Ed Green', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281E', 'professor_name': 'Ed Green', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281E', 'professor_name': 'Ed Green', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281F', 'professor_name': 'Camilla E Forsberg', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281F', 'professor_name': 'Camilla E Forsberg', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281F', 'professor_name': 'Camilla E Forsberg', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281G', 'professor_name': 'Ali Shariati', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281H', 'professor_name': 'David Haussler', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281H', 'professor_name': 'David Haussler', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281H', 'professor_name': 'David Haussler', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281J', 'professor_name': 'Benedict John Paten', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281J', 'professor_name': 'Benedict John Paten', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281J', 'professor_name': 'Benedict John Paten', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281L', 'professor_name': 'Todd M Lowe', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281L', 'professor_name': 'Todd M Lowe', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281L', 'professor_name': 'Todd M Lowe', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281M', 'professor_name': 'Karen Miga', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281M', 'professor_name': 'Karen Miga', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281M', 'professor_name': 'Karen Miga', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281N', 'professor_name': 'Angela Brooks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281N', 'professor_name': 'Angela Brooks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281N', 'professor_name': 'Angela Brooks', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281P', 'professor_name': 'Nader Pourmand', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281P', 'professor_name': 'Nader Pourmand', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281P', 'professor_name': 'Nader Pourmand', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281R', 'professor_name': 'Daniel H. Kim', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281R', 'professor_name': 'Daniel H. Kim', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281R', 'professor_name': 'Daniel H. Kim', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281T', 'professor_name': 'Tal Sharf', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281V', 'professor_name': 'Chris Vollmers', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281V', 'professor_name': 'Chris Vollmers', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281V', 'professor_name': 'Chris Vollmers', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281X', 'professor_name': 'Shelbi L Russell', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281X', 'professor_name': 'Shelbi L Russell', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281X', 'professor_name': 'Shelbi L Russell', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281Y', 'professor_name': 'Andy H.W. Yeh', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Fall24', 'class_name': 'BME281Z', 'professor_name': 'Russ Corbett-Detig', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Winter25', 'class_name': 'BME281Z', 'professor_name': 'Russ Corbett-Detig', 'section': 'Section 01'}
# {'department': 'Biomolecular Engineering', 'quarter': 'Spring25', 'class_name': 'BME281Z', 'professor_name': 'Russ Corbett-Detig', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM15', 'professor_name': 'David Manuel Torres-Mendoza', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM15', 'professor_name': 'David Manuel Torres-Mendoza', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM15', 'professor_name': 'David Manuel Torres-Mendoza', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM17', 'professor_name': 'Tela Favaloro', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM17', 'professor_name': 'Tela Favaloro', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM17', 'professor_name': 'Tela Favaloro', 'section': 'Section 03'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM17', 'professor_name': 'Tela Favaloro', 'section': 'Section 04'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM17', 'professor_name': 'Tela Favaloro', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM17', 'professor_name': 'Tela Favaloro', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM25', 'professor_name': 'Chris Yonge', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM26', 'professor_name': 'Chris Yonge', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM27', 'professor_name': 'Chris Yonge', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM80J', 'professor_name': 'Samantha Gorman', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM80J', 'professor_name': 'Nathan Altice', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM80J', 'professor_name': 'Nathan Altice', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM80K', 'professor_name': 'Noah G Wardrip-Fruin', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM80K', 'professor_name': 'Kate Ringland', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM80K', 'professor_name': 'Noah G Wardrip-Fruin', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM110', 'professor_name': 'Noah G Wardrip-Fruin', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM115', 'professor_name': 'Tela Favaloro', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM115', 'professor_name': 'Tela Favaloro', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM118', 'professor_name': 'David Lee', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM118', 'professor_name': 'Kate Ringland', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM118', 'professor_name': 'Jason Eshraghian', 'section': 'Section 03'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM118', 'professor_name': 'Leilani H Gilpin', 'section': 'Section 05'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM118', 'professor_name': 'David Lee', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM118', 'professor_name': 'Kate Ringland', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM118', 'professor_name': 'Jason Eshraghian', 'section': 'Section 03'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM118', 'professor_name': 'David Lee', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM118', 'professor_name': 'Kate Ringland', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM118', 'professor_name': 'Jason Eshraghian', 'section': 'Section 03'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM120', 'professor_name': 'Nathan Altice', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM120', 'professor_name': 'Jim Whitehead', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM121', 'professor_name': 'Adam M. Smith', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM121', 'professor_name': 'Markus Eger', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM121', 'professor_name': 'Zac Emerzian', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM122', 'professor_name': 'Joel Dreskin', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM123', 'professor_name': 'Graeme J Devine', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM125', 'professor_name': 'Tyler Coleman', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM130', 'professor_name': 'Katherine C Isbister', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM146', 'professor_name': 'Daniel G Shapiro', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM146', 'professor_name': 'Markus Eger', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM147', 'professor_name': 'Wes Modes', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM148', 'professor_name': 'Michael J Mateas', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM150', 'professor_name': 'Adam Sporka', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM150', 'professor_name': 'Brian M Hansen', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM169', 'professor_name': 'Wes Modes', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM170', 'professor_name': 'Samantha Gorman', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM170', 'professor_name': 'rjhangia', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM170', 'professor_name': 'Markus Eger', 'section': 'Section 03'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM170', 'professor_name': 'Graeme J Devine', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM171', 'professor_name': 'Tyler Coleman', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM171', 'professor_name': 'Tyler Coleman', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM171', 'professor_name': 'Markus Eger', 'section': 'Section 03'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM172', 'professor_name': 'Tyler Coleman', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM172', 'professor_name': 'Tyler Coleman', 'section': 'Section 02'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM176', 'professor_name': 'Jared N Pettitt', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM179', 'professor_name': 'Wes Modes', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM180', 'professor_name': 'Samantha Gorman', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM180', 'professor_name': 'Samantha Gorman', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM201', 'professor_name': 'Elin Carstensdottir', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM201', 'professor_name': 'Elin Carstensdottir', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM202', 'professor_name': 'Adam M. Smith', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM202', 'professor_name': 'Adam M. Smith', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM203', 'professor_name': 'Kate Ringland', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM203', 'professor_name': 'Kate Ringland', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM206', 'professor_name': 'Sri Hastuti Kurniawan', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM206', 'professor_name': 'Sri Hastuti Kurniawan', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM206', 'professor_name': 'Sri Hastuti Kurniawan', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM206', 'professor_name': 'Sri Hastuti Kurniawan', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM230', 'professor_name': 'Mahnaz Roshanaei', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM237', 'professor_name': 'Elin Carstensdottir', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM237', 'professor_name': 'Elin Carstensdottir', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM243', 'professor_name': 'David Lee', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM243', 'professor_name': 'David Lee', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM248', 'professor_name': 'Michael J Mateas', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM248', 'professor_name': 'Michael J Mateas', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM280G', 'professor_name': 'Jim Whitehead', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM280G', 'professor_name': 'Jim Whitehead', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM280G', 'professor_name': 'Jim Whitehead', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM280H', 'professor_name': 'Katherine C Isbister', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM280H', 'professor_name': 'Katherine C Isbister', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM280H', 'professor_name': 'Katherine C Isbister', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM280K', 'professor_name': 'Sri Hastuti Kurniawan', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM280K', 'professor_name': 'Sri Hastuti Kurniawan', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM280K', 'professor_name': 'Sri Hastuti Kurniawan', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM280P', 'professor_name': 'Magy Seif El-Nasr', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM280P', 'professor_name': 'Magy Seif El-Nasr', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM280P', 'professor_name': 'Magy Seif El-Nasr', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM280S', 'professor_name': 'David Lee', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM280S', 'professor_name': 'David Lee', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM280S', 'professor_name': 'David Lee', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM280W', 'professor_name': 'Nathan Altice', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM280W', 'professor_name': 'Nathan Altice', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM280W', 'professor_name': 'Nathan Altice', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Fall24', 'class_name': 'CMPM280X', 'professor_name': 'Noah G Wardrip-Fruin', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM280X', 'professor_name': 'Noah G Wardrip-Fruin', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM280X', 'professor_name': 'Noah G Wardrip-Fruin', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM290A', 'professor_name': 'Samantha Gorman', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Winter25', 'class_name': 'CMPM290A', 'professor_name': 'Samantha Gorman', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM290A', 'professor_name': 'Adam M. Smith', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM290A', 'professor_name': 'Adam M. Smith', 'section': 'Section 50'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM290K', 'professor_name': 'Katherine C Isbister', 'section': 'Section 01'}
# {'department': 'Computational Media', 'quarter': 'Spring25', 'class_name': 'CMPM290K', 'professor_name': 'Katherine C Isbister', 'section': 'Section 50'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE3', 'professor_name': 'Gerald B Moulds', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE3', 'professor_name': 'Gerald B Moulds', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE3', 'professor_name': 'Gerald B Moulds', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE12', 'professor_name': 'Sagnik Nath', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE12', 'professor_name': 'Marcelo Siero', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE12', 'professor_name': 'Sagnik Nath', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE12', 'professor_name': 'Marcelo Siero', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE12', 'professor_name': 'Sagnik Nath', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE12', 'professor_name': 'Marcelo Siero', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE13S', 'professor_name': 'Kerry Veenstra', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE13S', 'professor_name': 'Alex Rudnick', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE13S', 'professor_name': 'Kerry Veenstra', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE13S', 'professor_name': 'Alex Rudnick', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE13S', 'professor_name': 'Kerry Veenstra', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE13S', 'professor_name': 'Alex Rudnick', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE13S', 'professor_name': 'Kriti Bhargava', 'section': 'Section 03'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE16', 'professor_name': 'John T Musacchio', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE16', 'professor_name': 'Alexandra Kolla', 'section': 'Section 03'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE16', 'professor_name': 'Kyle A Miller', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE16', 'professor_name': 'Allen Van Gelder', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE16', 'professor_name': 'Patrick Tantalo', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE16', 'professor_name': 'Allen Van Gelder', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE20', 'professor_name': 'Larissa A Munishkina', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE20', 'professor_name': 'Oswald A Campesato', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE20', 'professor_name': 'Cormac A Flanagan', 'section': 'Section 03'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE20', 'professor_name': 'Hao Yue', 'section': 'Section 04'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE20', 'professor_name': 'Larissa A Munishkina', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE20', 'professor_name': 'Oswald A Campesato', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE20', 'professor_name': 'Benedict John Paten', 'section': 'Section 03'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE20', 'professor_name': 'Hao Yue', 'section': 'Section 04'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE20', 'professor_name': 'Larissa A Munishkina', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE20', 'professor_name': 'Oswald A Campesato', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE30', 'professor_name': 'Larissa A Munishkina', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE30', 'professor_name': 'Oswald A Campesato', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE30', 'professor_name': 'Larissa A Munishkina', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE30', 'professor_name': 'Oswald A Campesato', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE30', 'professor_name': 'Hao Yue', 'section': 'Section 03'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE30', 'professor_name': 'Larissa A Munishkina', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE30', 'professor_name': 'Oswald A Campesato', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE30', 'professor_name': 'Hao Yue', 'section': 'Section 03'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE40', 'professor_name': 'Lise Getoor', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE40', 'professor_name': 'Alex Rudnick', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE40', 'professor_name': 'Niloofar Montazeri', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE80A', 'professor_name': 'Roberto Manduchi', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE80N', 'professor_name': 'Richard J Graziani', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE80N', 'professor_name': 'Richard J Graziani', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE80N', 'professor_name': 'Christina Parsa', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE100', 'professor_name': 'Ethan Joseph Sifferman', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE100', 'professor_name': 'Dustin Richmond', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE100', 'professor_name': 'Ethan Joseph Sifferman', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE100L', 'professor_name': 'Ethan Joseph Sifferman', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE100L', 'professor_name': 'Ethan Joseph Sifferman', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE101', 'professor_name': 'Patrick Tantalo', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE101', 'professor_name': 'Yannis Demertzis', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE101', 'professor_name': 'Patrick Tantalo', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE101', 'professor_name': 'Niloofar Montazeri', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE101', 'professor_name': 'Allen Van Gelder', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE101', 'professor_name': 'Alex Pang', 'section': 'Section 02'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE101M', 'professor_name': 'Vaggos Chatziafratis', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE101M', 'professor_name': 'Daniel Fremont', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE101P', 'professor_name': 'Niloofar Montazeri', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE102', 'professor_name': 'Delbert D. Bailey', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE102', 'professor_name': 'Sungjin Im', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE102', 'professor_name': 'Delbert D. Bailey', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE103', 'professor_name': 'Delbert D. Bailey', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE103', 'professor_name': 'Daniel Fremont', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE105', 'professor_name': 'Vaggos Chatziafratis', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE107', 'professor_name': 'Patrick Tantalo', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE107', 'professor_name': 'Patrick Tantalo', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE107', 'professor_name': 'Patrick Tantalo', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE108', 'professor_name': 'Yannis Demertzis', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Spring25', 'class_name': 'CSE109', 'professor_name': 'Alexandra Kolla', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE111', 'professor_name': 'Ethan Joseph Sifferman', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE113', 'professor_name': 'Mohsen Lesani', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Fall24', 'class_name': 'CSE114A', 'professor_name': 'Owen Arden', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE114A', 'professor_name': 'Cormac A Flanagan', 'section': 'Section 01'}
# {'department': 'Computer Science and Engineering', 'quarter': 'Winter25', 'class_name': 'CSE114A', 'professor_name': 'Lindsey A Kuper', 'section': 'Section 02'}
# ...
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Winter25', 'class_name': 'ECE280N', 'professor_name': 'Ali Yanik', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Spring25', 'class_name': 'ECE280N', 'professor_name': 'Ali Yanik', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Fall24', 'class_name': 'ECE280O', 'professor_name': 'Holger Schmidt', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Winter25', 'class_name': 'ECE280O', 'professor_name': 'Holger Schmidt', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Spring25', 'class_name': 'ECE280O', 'professor_name': 'Holger Schmidt', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Winter25', 'class_name': 'ECE280Z', 'professor_name': 'Yu Zhang', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Spring25', 'class_name': 'ECE280Z', 'professor_name': 'Yu Zhang', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Fall24', 'class_name': 'ECE290', 'professor_name': 'Hao Ye', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Winter25', 'class_name': 'ECE290', 'professor_name': 'Hao Ye', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Spring25', 'class_name': 'ECE290', 'professor_name': 'Hao Ye', 'section': 'Section 01'}
# {'department': 'Electrical and Computer Engineering', 'quarter': 'Fall24', 'class_name': 'ECE291', 'professor_name': 'Michael Mikio Oye', 'section': 'Section 01'}
# {'department': 'Games and Playable Media', 'quarter': 'Winter25', 'class_name': 'GAME215', 'professor_name': 'Adam Sporka', 'section': 'Section 50'}
# {'department': 'Games and Playable Media', 'quarter': 'Fall24', 'class_name': 'GAME221', 'professor_name': 'Terry Smith', 'section': 'Section 50'}
# {'department': 'Games and Playable Media', 'quarter': 'Fall24', 'class_name': 'GAME271', 'professor_name': 'Zac Emerzian', 'section': 'Section 50'}
# {'department': 'Games and Playable Media', 'quarter': 'Winter25', 'class_name': 'GAME272', 'professor_name': 'Zac Emerzian', 'section': 'Section 50'}
# {'department': 'Games and Playable Media', 'quarter': 'Fall24', 'class_name': 'GAME280A', 'professor_name': 'Tad A Leckman', 'section': 'Section 50'}
# {'department': 'Games and Playable Media', 'quarter': 'Winter25', 'class_name': 'GAME280A', 'professor_name': 'Tad A Leckman', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Fall24', 'class_name': 'HCI200', 'professor_name': 'Elin Carstensdottir', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Fall24', 'class_name': 'HCI201', 'professor_name': 'Kate Ringland', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Winter25', 'class_name': 'HCI202A', 'professor_name': 'Ayesha Khalid', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Winter25', 'class_name': 'HCI202B', 'professor_name': 'Tyler Coleman', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Winter25', 'class_name': 'HCI220', 'professor_name': 'Mahnaz Roshanaei', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Spring25', 'class_name': 'HCI271', 'professor_name': 'Norman Makoto Su', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Fall24', 'class_name': 'HCI272', 'professor_name': 'Christina Chung', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Fall24', 'class_name': 'HCI290', 'professor_name': 'Yassi Moghaddam', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Winter25', 'class_name': 'HCI290', 'professor_name': 'Yassi Moghaddam', 'section': 'Section 50'}
# {'department': 'Human Computer Interaction', 'quarter': 'Spring25', 'class_name': 'HCI290', 'professor_name': 'Yassi Moghaddam', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Fall24', 'class_name': 'NLP201', 'professor_name': 'Jeffrey Flanigan', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Winter25', 'class_name': 'NLP202', 'professor_name': 'Jeffrey Flanigan', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Fall24', 'class_name': 'NLP220', 'professor_name': 'Jalal Mahmud', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Fall24', 'class_name': 'NLP243', 'professor_name': 'Amita Misra', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Winter25', 'class_name': 'NLP245', 'professor_name': 'Beth A Hockey', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Fall24', 'class_name': 'NLP255', 'professor_name': 'Beth A Hockey', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Spring25', 'class_name': 'NLP270', 'professor_name': 'Margaret Ilona Kroll', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Fall24', 'class_name': 'NLP271B', 'professor_name': 'Ian Lane', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Winter25', 'class_name': 'NLP271B', 'professor_name': 'Ian Lane', 'section': 'Section 01'}
# {'department': 'Natural Language Processing', 'quarter': 'Winter25', 'class_name': 'NLP280', 'professor_name': 'Jeffrey Flanigan', 'section': 'Section 50'}
# {'department': 'Natural Language Processing', 'quarter': 'Spring25', 'class_name': 'NLP280', 'professor_name': 'Ian Lane', 'section': 'Section 50'}
# {'department': 'Serious Games', 'quarter': 'Winter25', 'class_name': 'GAME215', 'professor_name': 'Adam Sporka', 'section': 'Section 50'}
# {'department': 'Serious Games', 'quarter': 'Fall24', 'class_name': 'GAME221', 'professor_name': 'Terry Smith', 'section': 'Section 50'}
# {'department': 'Serious Games', 'quarter': 'Fall24', 'class_name': 'GAME271', 'professor_name': 'Zac Emerzian', 'section': 'Section 50'}
# {'department': 'Serious Games', 'quarter': 'Winter25', 'class_name': 'GAME272', 'professor_name': 'Zac Emerzian', 'section': 'Section 50'}
# {'department': 'Serious Games', 'quarter': 'Fall24', 'class_name': 'GAME280A', 'professor_name': 'Tad A Leckman', 'section': 'Section 50'}
# {'department': 'Serious Games', 'quarter': 'Winter25', 'class_name': 'GAME280A', 'professor_name': 'Tad A Leckman', 'section': 'Section 50'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT5', 'professor_name': 'Yunan Wang', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT5', 'professor_name': 'Yunan Wang', 'section': 'Section 02'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT5', 'professor_name': 'Yunan Wang', 'section': 'Section 03'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT5', 'professor_name': 'Marcela Alfaro-Córdoba', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT5', 'professor_name': 'Yunan Wang', 'section': 'Section 02'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT5', 'professor_name': 'Yunan Wang', 'section': 'Section 03'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT5', 'professor_name': 'Marcela Alfaro-Córdoba', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT5', 'professor_name': 'Yunan Wang', 'section': 'Section 02'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT5', 'professor_name': 'Rebecca Killick', 'section': 'Section 03'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT7', 'professor_name': 'Marcela Alfaro Cordoba', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT7', 'professor_name': 'Yunan Wang', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT7', 'professor_name': 'Juhee Lee', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT7L', 'professor_name': 'Meini Tang', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT17', 'professor_name': 'Suzana Serboi', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT17', 'professor_name': 'Yonatan Katznelson', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT17', 'professor_name': 'Yonatan Katznelson', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT17L', 'professor_name': 'Subhra Saha', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT17L', 'professor_name': 'Subhra Saha', 'section': 'Section 02'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT17L', 'professor_name': 'Subhra Saha', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT17L', 'professor_name': 'Subhra Saha', 'section': 'Section 02'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT17L', 'professor_name': 'Subhra Saha', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT17L', 'professor_name': 'Subhra Saha', 'section': 'Section 02'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT80A', 'professor_name': 'Yik Lun Kei', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT80B', 'professor_name': 'Sangwon Hyun', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT131', 'professor_name': 'Bruno Sansó', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT131', 'professor_name': 'Juhee Lee', 'section': 'Section 02'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT131', 'professor_name': 'Marcela Alfaro-Córdoba', 'section': 'Section 02'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT131', 'professor_name': 'Richard Li', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT131', 'professor_name': 'Sangwon Hyun', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT131', 'professor_name': 'Yunan Wang', 'section': 'Section 02'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT132', 'professor_name': 'Yik Lun Kei', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT132', 'professor_name': 'Paul Parker', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT132', 'professor_name': 'Yik Lun Kei', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT200', 'professor_name': 'Raquel Prado', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT203', 'professor_name': 'Rebecca Killick', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT204', 'professor_name': 'Paul Parker', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT205', 'professor_name': 'Sangwon Hyun', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT205B', 'professor_name': 'Bruno Sansó', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT206B', 'professor_name': 'Juhee Lee', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT207', 'professor_name': 'Richard Li', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT208', 'professor_name': 'Paul Parker', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT209', 'professor_name': 'Athanasios Kottas', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT222', 'professor_name': 'Athanasios Kottas', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT223', 'professor_name': 'Raquel Prado', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT227', 'professor_name': 'Richard Li', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT243', 'professor_name': 'Athanasios Kottas', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT246', 'professor_name': 'Robert Lund', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT280B', 'professor_name': 'Paul A Parker', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT280B', 'professor_name': 'Yik Lun Kei', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Fall24', 'class_name': 'STAT280D', 'professor_name': 'Richard Li', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Winter25', 'class_name': 'STAT280D', 'professor_name': 'Sangwon Hyun', 'section': 'Section 01'}
# {'department': 'Statistics', 'quarter': 'Spring25', 'class_name': 'STAT280D', 'professor_name': 'Ju Hee Lee', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Fall24', 'class_name': 'TIM50', 'professor_name': 'Paul Vroomen', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Winter25', 'class_name': 'TIM50', 'professor_name': 'John T Musacchio', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Spring25', 'class_name': 'TIM50', 'professor_name': 'Paul Vroomen', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Winter25', 'class_name': 'TIM58', 'professor_name': 'Paul Vroomen', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Spring25', 'class_name': 'TIM80C', 'professor_name': 'Subhas Desa', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Spring25', 'class_name': 'TIM147', 'professor_name': 'Yi Zhang', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Fall24', 'class_name': 'TIM170', 'professor_name': 'Subhas Desa', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Winter25', 'class_name': 'TIM170', 'professor_name': 'Subhas Desa', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Spring25', 'class_name': 'TIM170', 'professor_name': 'Subhas Desa', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Fall24', 'class_name': 'TIM172A', 'professor_name': 'Subhas Desa', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Winter25', 'class_name': 'TIM172B', 'professor_name': 'Subhas Desa', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Fall24', 'class_name': 'TIM172P', 'professor_name': 'Subhas Desa', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Winter25', 'class_name': 'TIM172Q', 'professor_name': 'Subhas Desa', 'section': 'Section 01'}
# {'department': 'Technology & Information Management', 'quarter': 'Spring25', 'class_name': 'TIM175', 'professor_name': 'David Lee', 'section': 'Section 01'}
# Data successfully saved to ucsc_baskin_courses_2024.csv

# %%
import random

# based on:
# https://catalog.ucsc.edu/en/current/general-catalog/academic-units/baskin-engineering/computer-science-and-engineering/computer-science-bs/

# all courses that must be taken and have no option choices
must_take = {

    # lower divs
    "CSE 12": {"credits": 7, "prerequisites": [["CSE 5J", "CSE 20", "CSE 30", "BME 160"]]},
    "CSE 16": {"credits": 5, "prerequisites": [["MATH 19A", "MATH 19B", "MATH 11B", "AM 11B", "AM 15B", "ECON 11B"]]},
    "CSE 20": {"credits": 5, "prerequisites": []},
    "CSE 30": {"credits": 5, "prerequisites": [["CSE 20", "BME 160", "MATH 3", "MATH 11A", "MATH 19A", "AM 3", "AM 11A"]]},
    "CSE 40": {"credits": 5, "prerequisites": [["MATH 19B", "MATH 20B"], ["CSE 30"] ]},
    "CSE 13S": {"credits": 7, "prerequisites": [["CSE 12", "BME 160"]]},
    "ECE 30": {"credits": 5, "prerequisites": [["MATH 19B"]]},

    # upper divs
    "CSE 101": {"credits": 5, "prerequisites": [["CSE 12", "BME 160"], ["CSE 13E", "ECE 13", "CSE 13S"],
        ["CSE 16"], ["CSE 30"], ["MATH 11B", "MATH 19B", "MATH 20B", "AM 11B", "ECON 11B"]]},
    "CSE 101M": {"credits": 5, "prerequisites": [["CSE 101"]]},
    "CSE 120": {"credits": 5, "prerequisites": [["CSE 12"], ["CSE 13S", "CSE 13E", "ECE 13"]]},
    "CSE 130": {"credits": 5, "prerequisites": [["CSE 12"],["CSE 101"]]},
}

# must pick 1 calc 1 class
calc_1 = {
    "MATH 19A": {"credits": 5, "prerequisites": []},
    "MATH 20A": {"credits": 5, "prerequisites": []}
}

# must pick 1 calc 2 class
calc_2 = {
    "MATH 19B": {"credits": 5, "prerequisites": [["MATH 19A", "MATH 20A"]]},
    "MATH 20B": {"credits": 5, "prerequisites": [["MATH 20A"]]}
}

# must pick 1 calc 3 class
calc_3 = {
    "AM 30": {"credits": 5, "prerequisites": [["AM 10", "MATH 21"], ["MATH 19B", "MATH 20B"]]},
    "MATH 21": {"credits": 5, "prerequisites": [["MATH 19A"]]}
}

# must pick 1 one linear alg class
linear_alg = {
    "AM 10": {"credits": 5, "prerequisites": []},
    "MATH 21": {"credits": 5, "prerequisites": [["MATH 19A"]]}
}

# must pick 1 stats class
stats = {
    "STAT 131": {"credits": 5, "prerequisites": [["AM 11B", "ECON 11B", "MATH 11B", "MATH 19B", "MATH 20B"]]},
    "CSE 107": {"credits": 5, "prerequisites": [["CSE 16"], ["AM 30", "MATH 22", "MATH 23A"]]}
}

# must pick 1 theory class
theory = {
    "CSE 102": {"credits": 5, "prerequisites": [["CSE 101"]]},
    "CSE 103": {"credits": 5, "prerequisites": [["CSE 101"]]}
}

# must pick 1 programming lang class
theory = {
    "CSE 112": {"credits": 5, "prerequisites": [["CSE 101"]]},
    "CSE 114A": {"credits": 5, "prerequisites": [["CSE 101"]]}
}

# must take 3 elective fillers here, plus a capstone that counts as an elective (listed after)
electives = {
    "elective 1": {"credits": 5, "prerequisites": []},
    "elective 2": {"credits": 5, "prerequisites": []},
    "elective 3": {"credits": 5, "prerequisites": []},
}

# must pick 1 capstone that counts as an elective
capstone = {
    "CSE 110B": {"credits": 5, "prerequisites": [["CSE 110A"]]},
    "CSE 115C": {"credits": 5, "prerequisites": [["CSE 115B"]]},
    "CSE 115D": {"credits": 5, "prerequisites": [["CSE 115A"]]},
    "CSE 121": {"credits": 7, "prerequisites": [["CSE 12", "CSE 100", "CSE 100L"],
            ["CSE 13E", "CSE 13S", "ECE 13", "CSE 15", "CSE 15L"],
            ["ECE 101", "ECE 101L", "PHYS 5C", "PHYS 5N"]
        ]
    },
    "CSE 134": {"credits": 5, "prerequisites": [["CSE 120", "CSE 130"]]},
    "CSE 138": {"credits": 5, "prerequisites": [["CSE 130", "CSE 131"]]},
    "CSE 140": {"credits": 5, "prerequisites": [["CSE 101", ["CSE 40", "STAT 132"]]]},
    "CSE 143": {
        "credits": 5,
        "prerequisites": [
            ["CSE 101"],
            ["CSE 107", "STAT 131"],
            ["CSE 40"]
        ]
    },
    "CSE 144": {
        "credits": 5,
        "prerequisites": [
            ["CSE 40", "STAT 132"],
            ["CSE 101"]
        ]
    },
    "CSE 145": {
        "credits": 5,
        "prerequisites": [
            ["CSE 15", "CSE 15L"],
            ["CSE 30"],
            ["CSE 13S"],
            ["AM 30", "MATH 22", "MATH 23A"],
            ["STAT 5", "CSE 107", "STAT 131"],
            ["AM 10", "MATH 21"],
            ["CSE 16", "ECON 113"]
        ]
    },
    "CSE 156": {
        "credits": 5,
        "prerequisites": [["CSE 150", "CSE 101"]],
        "concurrent": "CSE 156L"
    },
    "CSE 156L": {
        "credits": 2,
        "prerequisites": [["CSE 150", "CSE 101"]],
        "concurrent": "CSE 156"
    },
    "CSE 157": {
        "credits": 7,
        "prerequisites": [["CSE 121", "CSE 150"]]
    },
    "CSE 160": {
        "credits": 7,
        "prerequisites": [["CSE 101", ["MATH 21", "AM 10"]]]
    },
    "CSE 161": {
        "credits": 5,
        "prerequisites": [["CSE 160", "equivalent"]],
        "concurrent": "CSE 161L"
    },
    "CSE 161L": {
        "credits": 2,
        "concurrent": "CSE 161"
    },
    "CSE 162": {
        "credits": 5,
        "prerequisites": [["CSE 160", "equivalent"]],
        "concurrent": "CSE 162L"
    },
    "CSE 162L": {
        "credits": 2,
        "concurrent": "CSE 162"
    },
    "CSE 163": {
        "credits": 5,
        "prerequisites": [["CSE 101"]]
    },
    "CSE 168": {
        "credits": 7,
        "prerequisites": [["CSE 160"]]
    },
    "CSE 181": {
        "credits": 5,
        "prerequisites": [["CSE 180", "CSE 130"]]
    },
    "CSE 183": {
        "credits": 5,
        "prerequisites": [
            ["CSE 15", "CSE 15L"],
            ["CMPM 35"],
            ["CSE 101"]
        ]
    },
    "CSE 184": {
        "credits": 5,
        "prerequisites": [["CSE 101"]]
    },
    "CSE 187": {
        "credits": 5,
        "prerequisites": [["CSE 186"]]
    },
    "CMPM 172": {
        "credits": 7,
        "prerequisites": [["CMPM 171"]]
    },
}

# %%
import random

# based on:
# https://catalog.ucsc.edu/en/current/general-catalog/academic-units/baskin-engineering/computer-science-and-engineering/computer-science-bs/

# all courses that must be taken and have no option choices
must_take = {

    # lower divs
    "CSE 12": {"credits": 7, "prerequisites": [["CSE 5J", "CSE 20", "CSE 30", "BME 160"]]},
    "CSE 16": {"credits": 5, "prerequisites": [["MATH 19A", "MATH 19B", "MATH 11B", "AM 11B", "AM 15B", "ECON 11B"]]},
    "CSE 20": {"credits": 5, "prerequisites": []},
    "CSE 30": {"credits": 5, "prerequisites": [["CSE 20", "BME 160", "MATH 3", "MATH 11A", "MATH 19A", "AM 3", "AM 11A"]]},
    "CSE 40": {"credits": 5, "prerequisites": [["MATH 19B", "MATH 20B"], ["CSE 30"] ]},
    "CSE 13S": {"credits": 7, "prerequisites": [["CSE 12", "BME 160"]]},
    "ECE 30": {"credits": 5, "prerequisites": [["MATH 19B"]]},

    # upper divs
    "CSE 101": {"credits": 5, "prerequisites": [["CSE 12", "BME 160"], ["CSE 13E", "ECE 13", "CSE 13S"],
        ["CSE 16"], ["CSE 30"], ["MATH 11B", "MATH 19B", "MATH 20B", "AM 11B", "ECON 11B"]]},
    "CSE 101M": {"credits": 5, "prerequisites": [["CSE 101"]]},
    "CSE 120": {"credits": 5, "prerequisites": [["CSE 12"], ["CSE 13S", "CSE 13E", "ECE 13"]]},
    "CSE 130": {"credits": 5, "prerequisites": [["CSE 12"],["CSE 101"]]},
}

# must pick 1 calc 1 class
calc_1 = {
    "MATH 19A": {"credits": 5, "prerequisites": []},
    "MATH 20A": {"credits": 5, "prerequisites": []}
}

# must pick 1 calc 2 class
calc_2 = {
    "MATH 19B": {"credits": 5, "prerequisites": [["MATH 19A", "MATH 20A"]]},
    "MATH 20B": {"credits": 5, "prerequisites": [["MATH 20A"]]}
}

# must pick 1 calc 3 class
calc_3 = {
    "AM 30": {"credits": 5, "prerequisites": [["AM 10", "MATH 21"], ["MATH 19B", "MATH 20B"]]},
    "MATH 23A": {"credits": 5, "prerequisites": [["MATH 19A"]]}
}

# must pick 1 one linear alg class
linear_alg = {
    "AM 10": {"credits": 5, "prerequisites": []},
    "MATH 21": {"credits": 5, "prerequisites": [["MATH 19A"]]}
}

# must pick 1 stats class
stats = {
    "STAT 131": {"credits": 5, "prerequisites": [["AM 11B", "ECON 11B", "MATH 11B", "MATH 19B", "MATH 20B"]]},
    "CSE 107": {"credits": 5, "prerequisites": [["CSE 16"], ["AM 30", "MATH 22", "MATH 23A"]]}
}

# must pick 1 theory class
theory = {
    "CSE 102": {"credits": 5, "prerequisites": [["CSE 101"]]},
    "CSE 103": {"credits": 5, "prerequisites": [["CSE 101"]]}
}

# must pick 1 programming lang class
theory = {
    "CSE 112": {"credits": 5, "prerequisites": [["CSE 101"]]},
    "CSE 114A": {"credits": 5, "prerequisites": [["CSE 101"]]}
}

# must take 3 elective fillers here, plus a capstone that counts as an elective (listed after)
electives = {
    "elective 1": {"credits": 5, "prerequisites": []},
    "elective 2": {"credits": 5, "prerequisites": []},
    "elective 3": {"credits": 5, "prerequisites": []},
}

# must pick 1 capstone that counts as an elective
capstone = {
    "CSE 110B": {"credits": 5, "prerequisites": [["CSE 110A"]]},
    "CSE 115C": {"credits": 5, "prerequisites": [["CSE 115B"]]},
    "CSE 115D": {"credits": 5, "prerequisites": [["CSE 115A"]]},
    "CSE 121": {"credits": 7, "prerequisites": [["CSE 12", "CSE 100", "CSE 100L"],
            ["CSE 13E", "CSE 13S", "ECE 13", "CSE 15", "CSE 15L"],
            ["ECE 101", "ECE 101L", "PHYS 5C", "PHYS 5N"]
        ]
    },
    "CSE 134": {"credits": 5, "prerequisites": [["CSE 120", "CSE 130"]]},
    "CSE 138": {"credits": 5, "prerequisites": [["CSE 130", "CSE 131"]]},
    "CSE 140": {"credits": 5, "prerequisites": [["CSE 101", ["CSE 40", "STAT 132"]]]},
    "CSE 143": {
        "credits": 5,
        "prerequisites": [
            ["CSE 101"],
            ["CSE 107", "STAT 131"],
            ["CSE 40"]
        ]
    },
    "CSE 144": {
        "credits": 5,
        "prerequisites": [
            ["CSE 40", "STAT 132"],
            ["CSE 101"]
        ]
    },
    "CSE 145": {
        "credits": 5,
        "prerequisites": [
            ["CSE 15", "CSE 15L"],
            ["CSE 30"],
            ["CSE 13S"],
            ["AM 30", "MATH 22", "MATH 23A"],
            ["STAT 5", "CSE 107", "STAT 131"],
            ["AM 10", "MATH 21"],
            ["CSE 16", "ECON 113"]
        ]
    },
    "CSE 156": {
        "credits": 5,
        "prerequisites": [["CSE 150", "CSE 101"]],
        "concurrent": "CSE 156L"
    },
    "CSE 156L": {
        "credits": 2,
        "prerequisites": [["CSE 150", "CSE 101"]],
        "concurrent": "CSE 156"
    },
    "CSE 157": {
        "credits": 7,
        "prerequisites": [["CSE 121", "CSE 150"]]
    },
    "CSE 160": {
        "credits": 7,
        "prerequisites": [["CSE 101", ["MATH 21", "AM 10"]]]
    },
    "CSE 161": {
        "credits": 5,
        "prerequisites": [["CSE 160", "equivalent"]],
        "concurrent": "CSE 161L"
    },
    "CSE 161L": {
        "credits": 2,
        "concurrent": "CSE 161"
    },
    "CSE 162": {
        "credits": 5,
        "prerequisites": [["CSE 160", "equivalent"]],
        "concurrent": "CSE 162L"
    },
    "CSE 162L": {
        "credits": 2,
        "concurrent": "CSE 162"
    },
    "CSE 163": {
        "credits": 5,
        "prerequisites": [["CSE 101"]]
    },
    "CSE 168": {
        "credits": 7,
        "prerequisites": [["CSE 160"]]
    },
    "CSE 181": {
        "credits": 5,
        "prerequisites": [["CSE 180", "CSE 130"]]
    },
    "CSE 183": {
        "credits": 5,
        "prerequisites": [
            ["CSE 15", "CSE 15L"],
            ["CMPM 35"],
            ["CSE 101"]
        ]
    },
    "CSE 184": {
        "credits": 5,
        "prerequisites": [["CSE 101"]]
    },
    "CSE 187": {
        "credits": 5,
        "prerequisites": [["CSE 186"]]
    },
    "CMPM 172": {
        "credits": 7,
        "prerequisites": [["CMPM 171"]]
    },
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7325b4c5e2c3> in <cell line: 55>()
#      53
#      54 # Generate and print a sample schedule
# ---> 55 sample_schedule = generate_schedule()
#      56 for term_num, term_courses in enumerate(sample_schedule, start=1):
#      57     print(f"Term {term_num}: {', '.join(term_courses)}")
#
# <ipython-input-5-7325b4c5e2c3> in generate_schedule()
#      40         while len(term_courses) < 3 and remaining_courses:  # Aim for 3 courses per term
#      41             course = random.choice(remaining_courses)
# ---> 42             if prerequisites_met(course, completed_courses):
#      43                 term_courses.append(course)
#      44                 completed_courses.add(course)
#
# <ipython-input-5-7325b4c5e2c3> in prerequisites_met(course, completed_courses)
#      21     prereqs = all_courses[course]["prerequisites"]
#      22     for or_group in prereqs:
# ---> 23         if any(prereq in completed_courses for prereq in or_group):
#      24             continue
#      25         else:
#
# <ipython-input-5-7325b4c5e2c3> in <genexpr>(.0)
#      21     prereqs = all_courses[course]["prerequisites"]
#      22     for or_group in prereqs:
# ---> 23         if any(prereq in completed_courses for prereq in or_group):
#      24             continue
#      25         else:
#
# TypeError: unhashable type: 'list'

# %%
import random

def can_take_course(course, prereqs, completed_courses):
  # print(course)
  # print(prereqs)
  # print("\n")
  satisfied = 0
  for prereq in prereqs:
    if len(prereq) > 1:
      for option in prereq:
        if option in completed_courses:
          satisfied += 1
          break
    else:
      if prereq[0] in completed_courses:
        satisfied += 1
  if satisfied == len(prereqs):
    return True
  return False

def calc_courses():

    # select which calculus class to take
    calc1_course = random.choice(list(calc_1.keys()))

    if calc1_course == "MATH 19A":
      calc2_course = "MATH 19B"
    else: # taking honors calc series
      calc2_course = "MATH 20B"

    calc3_course = random.choice(list(calc_3.keys()))

    return calc1_course, calc2_course, calc3_course


def generate_schedule(courses):
    schedule = [[], [], [],
                [], [], [],
                [], [], [],
                ["ELECTIVE"], ["ELECTIVE"], ["ELECTIVE", "CAPSTONE"],]

    completed_courses = set()

    ### calc 1-3 ###

    [calc1_course, calc2_course, calc3_course] = calc_courses()

    start_calc_quarter = random.randint(0, 0)

    schedule[start_calc_quarter].append(calc1_course)
    schedule[start_calc_quarter+1].append(calc2_course)
    schedule[start_calc_quarter+2].append(calc3_course)

    print(f"calcs: {schedule}")

    quarter = 0

    ### linear alg ###

    # select which linear alg class to take
    alg_course = random.choice(list(linear_alg.keys()))

    if alg_course == "AM 10":
      start_alg_quarter = random.randint(0, 4)
    else:
      start_alg_quarter = random.randint(start_calc_quarter+1, 4)
    schedule[start_alg_quarter].append(alg_course)

    print(f"after adding linear alg: {schedule}\n")

    ### stats ###

    # select which stats class to take, and then add it to courses
    stats_course = random.choice(list(stats.keys()))

    if stats_course == "CSE 107":
      courses["CSE 107"] = {"credits": 5, "prerequisites": [["CSE 16"], ["AM 30", "MATH 22", "MATH 23A"]]}
    else:
      courses["STAT 131"] = {"credits": 5, "prerequisites": [["AM 11B", "ECON 11B", "MATH 11B", "MATH 19B", "MATH 20B"]]}

    print(f"after adding STATS TO COURSES: {courses}\n")


    ### theory ###

    # select which stats class to take, and then add it to courses
    theory_course = random.choice(list(theory.keys()))

    if theory_course == "CSE 102":
      courses["CSE 102"] = {"credits": 5, "prerequisites": [["CSE 101"]]}
    else:
      courses["CSE 103"] = {"credits": 5, "prerequisites": [["CSE 101"]]}

    print(f"after adding theory TO COURSES: {courses}\n")


    ### pl ###

    # select which pl class to take, and then add it to courses
    pl_course = random.choice(list(pl.keys()))


    if pl_course == "CSE 112":
      courses["CSE 112"] = {"credits": 5, "prerequisites": [["CSE 101"]]}
      print(courses["CSE 112"])
    else:
      courses["CSE 114A"] = {"credits": 5, "prerequisites": [["CSE 101"]]}
      print(courses["CSE 114A"])


    ### DC ###

    # select which DC class to take, and then add it to courses
    DC_course = random.choice(list(DCs.keys()))
    # print(f"DC: {DC_course}, {DCs[DC_course]}")

    courses[DC_course] = DCs[DC_course]
    print(f"\n\nDC course: {DC_course}")
    print(f"DC prereqs: {courses[DC_course]}\n\n")


    ### capstone ###

    # # select which capstone class to take, and then add it to courses
    # capstone_course = random.choice(list(capstones.keys()))
    # print(f"CAPSTONE: {capstone_course}, {capstones[capstone_course]}")

    # courses[capstone_course] = capstones[capstone_course]
    # print(courses[capstone_course])


    # if capstone_course == "CSE 112":
    #   courses["CSE 112"] = {"credits": 5, "prerequisites": [["CSE 101"]]}
    # else:
    #   courses["CSE 114A"] = {"credits": 5, "prerequisites": [["CSE 101"]]}


    while courses:

        if quarter != 0:
          print(f"here schedule: {schedule}")
          print(quarter-1)
          for c in schedule[quarter-1]:
            completed_courses.add(c)

        # current quarter's classes
        current_quarter = []

        # list of available courses that meet prerequisites
        available_courses = []

        # collect courses that can be taken this quarter
        for course in courses:
          prereq = courses[course]["prerequisites"]
          if can_take_course(course, prereq, completed_courses):
            available_courses.append(course)

        print(f"what can be taken this quarter: {available_courses}")

        # randomly select up to 2 courses from the available courses
        random.shuffle(available_courses)  # shuffle the available courses for randomness
        # alr = len(schedule[quarter])
        for course in available_courses[:2]:
          if len(schedule[quarter]) == 2:
            break
          current_quarter.append(course)
          completed_courses.add(course)
          del courses[course]
          # add the course to the schedule
          schedule[quarter].append(course)



        print(f"updated schedule: {schedule}\n")

        # stop if we can't take any more courses this quarter
        # if not current_quarter:
        #     break

        quarter += 1

    return schedule

# define the courses as given
must_take = {
    "CSE 12": {"credits": 7, "prerequisites": [["CSE 5J", "CSE 20", "CSE 30", "BME 160"]]},
    "CSE 16": {"credits": 5, "prerequisites": [["MATH 20A", "MATH 19A", "MATH 19B", "MATH 11B", "AM 11B", "AM 15B", "ECON 11B"]]},
    "CSE 20": {"credits": 5, "prerequisites": []},
    "CSE 30": {"credits": 5, "prerequisites": [["CSE 20", "BME 160", "MATH 3", "MATH 11A", "MATH 19A", "AM 3", "AM 11A"]]},
    "CSE 40": {"credits": 5, "prerequisites": [["MATH 19B", "MATH 20B"], ["CSE 30"]]},
    "CSE 13S": {"credits": 7, "prerequisites": [["CSE 12", "BME 160"]]},
    "ECE 30": {"credits": 5, "prerequisites": [["MATH 19B", "MATH 20B"]]},

    "CSE 101": {"credits": 5, "prerequisites": [["CSE 12", "BME 160"], ["CSE 13E", "ECE 13", "CSE 13S"],
        ["CSE 16"], ["CSE 30"], ["MATH 11B", "MATH 19B", "MATH 20B", "AM 11B", "ECON 11B"]]},
    "CSE 101M": {"credits": 5, "prerequisites": [["CSE 101"]]},
    "CSE 120": {"credits": 5, "prerequisites": [["CSE 12"], ["CSE 13S", "CSE 13E", "ECE 13"]]},
    "CSE 130": {"credits": 5, "prerequisites": [["CSE 12"],["CSE 101"]]}
}

# must pick 1 calc 1 class
calc_1 = {
    "MATH 19A": {"credits": 5, "prerequisites": []},
    "MATH 20A": {"credits": 5, "prerequisites": []}
}

# must pick 1 calc 2 class
calc_2 = {
    "MATH 19B": {"credits": 5, "prerequisites": [["MATH 19A", "MATH 20A"]]},
    "MATH 20B": {"credits": 5, "prerequisites": [["MATH 20A"]]}
}

# must pick 1 calc 3 class
calc_3 = {
    "AM 30": {"credits": 5, "prerequisites": [["AM 10", "MATH 21"], ["MATH 19B", "MATH 20B"]]},
    "MATH 23A": {"credits": 5, "prerequisites": [["MATH 19A"]]}
}

# must pick 1 one linear alg class
linear_alg = {
    "AM 10": {"credits": 5, "prerequisites": []},
    "MATH 21": {"credits": 5, "prerequisites": [["MATH 19A"]]}
}

# must pick 1 stats class
stats = {
    "STAT 131": {"credits": 5, "prerequisites": [["AM 11B", "ECON 11B", "MATH 11B", "MATH 19B", "MATH 20B"]]},
    "CSE 107": {"credits": 5, "prerequisites": [["CSE 16"], ["AM 30", "MATH 22", "MATH 23A"]]}
}

# must pick 1 theory class
theory = {
    "CSE 102": {"credits": 5, "prerequisites": [["CSE 101"]]},
    "CSE 103": {"credits": 5, "prerequisites": [["CSE 101"]]}
}

# must pick 1 programming lang class
pl = {
    "CSE 112": {"credits": 5, "prerequisites": [["CSE 101"]]},
    "CSE 114A": {"credits": 5, "prerequisites": [["CSE 101"]]}
}


# must take 3 elective fillers here, plus a capstone that counts as an elective (listed after)
electives = {
    "elective 1": {"credits": 5, "prerequisites": []},
    "elective 2": {"credits": 5, "prerequisites": []},
    "elective 3": {"credits": 5, "prerequisites": []},
}

capstones = {
    "CSE 110B": {"credits": 5, "prerequisites": [["CSE 110A"]]},
    "CSE 115C": {"credits": 5, "prerequisites": [["CSE 115B"]]},
    "CSE 115D": {"credits": 5, "prerequisites": [["CSE 115A"]]},
    "CSE 121": {"credits": 7, "prerequisites": [["CSE 12", "CSE 100", "CSE 100L"],
            ["CSE 13E", "CSE 13S", "ECE 13", "CSE 15", "CSE 15L"],
            ["ECE 101", "ECE 101L", "PHYS 5C", "PHYS 5N"]
        ]
    },
    "CSE 134": {"credits": 5, "prerequisites": [["CSE 120", "CSE 130"]]},
    "CSE 138": {"credits": 5, "prerequisites": [["CSE 130", "CSE 131"]]},
    "CSE 140": {"credits": 5, "prerequisites": [["CSE 101", ["CSE 40", "STAT 132"]]]},
    "CSE 143": {
        "credits": 5,
        "prerequisites": [
            ["CSE 101"],
            ["CSE 107", "STAT 131"],
            ["CSE 40"]
        ]
    },
    "CSE 144": {
        "credits": 5,
        "prerequisites": [
            ["CSE 40", "STAT 132"],
            ["CSE 101"]
        ]
    },
    "CSE 145": {
        "credits": 5,
        "prerequisites": [
            ["CSE 15", "CSE 15L"],
            ["CSE 30"],
            ["CSE 13S"],
            ["AM 30", "MATH 22", "MATH 23A"],
            ["STAT 5", "CSE 107", "STAT 131"],
            ["AM 10", "MATH 21"],
            ["CSE 16", "ECON 113"]
        ]
    },
    "CSE 156": {
        "credits": 5,
        "prerequisites": [["CSE 150", "CSE 101"]],
        "concurrent": "CSE 156L"
    },
    "CSE 156L": {
        "credits": 2,
        "prerequisites": [["CSE 150", "CSE 101"]],
        "concurrent": "CSE 156"
    },
    "CSE 157": {
        "credits": 7,
        "prerequisites": [["CSE 121", "CSE 150"]]
    },
    "CSE 160": {
        "credits": 7,
        "prerequisites": [["CSE 101", ["MATH 21", "AM 10"]]]
    },
    "CSE 161": {
        "credits": 5,
        "prerequisites": [["CSE 160", "equivalent"]],
        "concurrent": "CSE 161L"
    },
    "CSE 161L": {
        "credits": 2,
        "concurrent": "CSE 161"
    },
    "CSE 162": {
        "credits": 5,
        "prerequisites": [["CSE 160", "equivalent"]],
        "concurrent": "CSE 162L"
    },
    "CSE 162L": {
        "credits": 2,
        "concurrent": "CSE 162"
    },
    "CSE 163": {
        "credits": 5,
        "prerequisites": [["CSE 101"]]
    },
    "CSE 168": {
        "credits": 7,
        "prerequisites": [["CSE 160"]]
    },
    "CSE 181": {
        "credits": 5,
        "prerequisites": [["CSE 180", "CSE 130"]]
    },
    "CSE 183": {
        "credits": 5,
        "prerequisites": [
            ["CSE 15", "CSE 15L"],
            ["CMPM 35"],
            ["CSE 101"]
        ]
    },
    "CSE 184": {
        "credits": 5,
        "prerequisites": [["CSE 101"]]
    },
    "CSE 187": {
        "credits": 5,
        "prerequisites": [["CSE 186"]]
    },
    "CMPM 172": {
        "credits": 7,
        "prerequisites": [["CMPM 171"]]
    },
}

# must pick 1 DC course

DCs = {
    "CSE 115A": {"credits": 5, "prerequisites": [["CSE 101"], ["CSE 130"]]},
    "CSE 185E": {"credits": 5, "prerequisites": [["CSE 30", "CSE 12"]]},
    "CSE 185S": {"credits": 5, "prerequisites": [["CSE 101"], ["CSE 101", "CSE 101M", "CSE 120", "CSE 130"]]},
    "CSE 195": {"credits": 5, "prerequisites": []}
}


# generate the schedule
course_schedule = generate_schedule(must_take)

# print the schedule
for quarter, courses in enumerate(course_schedule, start=1):
    print(f"Quarter {quarter}: {', '.join(courses) if courses else 'No courses available'}")
# Out:
# calcs: [['MATH 19A'], ['MATH 19B'], ['MATH 23A'], [], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# after adding linear alg: [['MATH 19A'], ['MATH 19B'], ['MATH 23A', 'AM 10'], [], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# after adding STATS TO COURSES: {'CSE 12': {'credits': 7, 'prerequisites': [['CSE 5J', 'CSE 20', 'CSE 30', 'BME 160']]}, 'CSE 16': {'credits': 5, 'prerequisites': [['MATH 20A', 'MATH 19A', 'MATH 19B', 'MATH 11B', 'AM 11B', 'AM 15B', 'ECON 11B']]}, 'CSE 20': {'credits': 5, 'prerequisites': []}, 'CSE 30': {'credits': 5, 'prerequisites': [['CSE 20', 'BME 160', 'MATH 3', 'MATH 11A', 'MATH 19A', 'AM 3', 'AM 11A']]}, 'CSE 40': {'credits': 5, 'prerequisites': [['MATH 19B', 'MATH 20B'], ['CSE 30']]}, 'CSE 13S': {'credits': 7, 'prerequisites': [['CSE 12', 'BME 160']]}, 'ECE 30': {'credits': 5, 'prerequisites': [['MATH 19B', 'MATH 20B']]}, 'CSE 101': {'credits': 5, 'prerequisites': [['CSE 12', 'BME 160'], ['CSE 13E', 'ECE 13', 'CSE 13S'], ['CSE 16'], ['CSE 30'], ['MATH 11B', 'MATH 19B', 'MATH 20B', 'AM 11B', 'ECON 11B']]}, 'CSE 101M': {'credits': 5, 'prerequisites': [['CSE 101']]}, 'CSE 120': {'credits': 5, 'prerequisites': [['CSE 12'], ['CSE 13S', 'CSE 13E', 'ECE 13']]}, 'CSE 130': {'credits': 5, 'prerequisites': [['CSE 12'], ['CSE 101']]}, 'CSE 107': {'credits': 5, 'prerequisites': [['CSE 16'], ['AM 30', 'MATH 22', 'MATH 23A']]}}
#
# after adding theory TO COURSES: {'CSE 12': {'credits': 7, 'prerequisites': [['CSE 5J', 'CSE 20', 'CSE 30', 'BME 160']]}, 'CSE 16': {'credits': 5, 'prerequisites': [['MATH 20A', 'MATH 19A', 'MATH 19B', 'MATH 11B', 'AM 11B', 'AM 15B', 'ECON 11B']]}, 'CSE 20': {'credits': 5, 'prerequisites': []}, 'CSE 30': {'credits': 5, 'prerequisites': [['CSE 20', 'BME 160', 'MATH 3', 'MATH 11A', 'MATH 19A', 'AM 3', 'AM 11A']]}, 'CSE 40': {'credits': 5, 'prerequisites': [['MATH 19B', 'MATH 20B'], ['CSE 30']]}, 'CSE 13S': {'credits': 7, 'prerequisites': [['CSE 12', 'BME 160']]}, 'ECE 30': {'credits': 5, 'prerequisites': [['MATH 19B', 'MATH 20B']]}, 'CSE 101': {'credits': 5, 'prerequisites': [['CSE 12', 'BME 160'], ['CSE 13E', 'ECE 13', 'CSE 13S'], ['CSE 16'], ['CSE 30'], ['MATH 11B', 'MATH 19B', 'MATH 20B', 'AM 11B', 'ECON 11B']]}, 'CSE 101M': {'credits': 5, 'prerequisites': [['CSE 101']]}, 'CSE 120': {'credits': 5, 'prerequisites': [['CSE 12'], ['CSE 13S', 'CSE 13E', 'ECE 13']]}, 'CSE 130': {'credits': 5, 'prerequisites': [['CSE 12'], ['CSE 101']]}, 'CSE 107': {'credits': 5, 'prerequisites': [['CSE 16'], ['AM 30', 'MATH 22', 'MATH 23A']]}, 'CSE 103': {'credits': 5, 'prerequisites': [['CSE 101']]}}
#
# {'credits': 5, 'prerequisites': [['CSE 101']]}
#
#
# DC course: CSE 115A
# DC prereqs: {'credits': 5, 'prerequisites': [['CSE 101'], ['CSE 130']]}
#
#
# what can be taken this quarter: ['CSE 20']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B'], ['MATH 23A', 'AM 10'], [], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# here schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B'], ['MATH 23A', 'AM 10'], [], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# 0
# what can be taken this quarter: ['CSE 12', 'CSE 16', 'CSE 30']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], [], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# here schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], [], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# 1
# what can be taken this quarter: ['CSE 12', 'CSE 30', 'ECE 30']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], [], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# here schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], [], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# 2
# what can be taken this quarter: ['CSE 12', 'CSE 30', 'ECE 30', 'CSE 107']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# here schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], [], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# 3
# what can be taken this quarter: ['CSE 40', 'CSE 13S', 'ECE 30', 'CSE 107']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# here schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], [], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# 4
# what can be taken this quarter: ['CSE 13S', 'CSE 107']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], ['CSE 13S', 'CSE 107'], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# here schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], ['CSE 13S', 'CSE 107'], [], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# 5
# what can be taken this quarter: ['CSE 101', 'CSE 120']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], ['CSE 13S', 'CSE 107'], ['CSE 120', 'CSE 101'], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# here schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], ['CSE 13S', 'CSE 107'], ['CSE 120', 'CSE 101'], [], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# 6
# what can be taken this quarter: ['CSE 101M', 'CSE 130', 'CSE 103', 'CSE 114A']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], ['CSE 13S', 'CSE 107'], ['CSE 120', 'CSE 101'], ['CSE 130', 'CSE 101M'], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# here schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], ['CSE 13S', 'CSE 107'], ['CSE 120', 'CSE 101'], ['CSE 130', 'CSE 101M'], [], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# 7
# what can be taken this quarter: ['CSE 103', 'CSE 114A', 'CSE 115A']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], ['CSE 13S', 'CSE 107'], ['CSE 120', 'CSE 101'], ['CSE 130', 'CSE 101M'], ['CSE 114A', 'CSE 115A'], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# here schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], ['CSE 13S', 'CSE 107'], ['CSE 120', 'CSE 101'], ['CSE 130', 'CSE 101M'], ['CSE 114A', 'CSE 115A'], ['ELECTIVE'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
# 8
# what can be taken this quarter: ['CSE 103']
# updated schedule: [['MATH 19A', 'CSE 20'], ['MATH 19B', 'CSE 16'], ['MATH 23A', 'AM 10'], ['CSE 12', 'CSE 30'], ['ECE 30', 'CSE 40'], ['CSE 13S', 'CSE 107'], ['CSE 120', 'CSE 101'], ['CSE 130', 'CSE 101M'], ['CSE 114A', 'CSE 115A'], ['ELECTIVE', 'CSE 103'], ['ELECTIVE'], ['ELECTIVE', 'CAPSTONE']]
#
# Quarter 1: MATH 19A, CSE 20
# Quarter 2: MATH 19B, CSE 16
# Quarter 3: MATH 23A, AM 10
# Quarter 4: CSE 12, CSE 30
# Quarter 5: ECE 30, CSE 40
# Quarter 6: CSE 13S, CSE 107
# Quarter 7: CSE 120, CSE 101
# Quarter 8: CSE 130, CSE 101M
# Quarter 9: CSE 114A, CSE 115A
# Quarter 10: ELECTIVE, CSE 103
# Quarter 11: ELECTIVE
# Quarter 12: ELECTIVE, CAPSTONE
